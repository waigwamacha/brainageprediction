# %% [markdown]
# #### Train XGBoost Models
# - There are three models trained. One trained male, the other on female, and the third one on both males and female (all) data

# %%
from datetime import datetime
from pyprojroot import here

import sys
import warnings

import matplotlib.pyplot as plt
import pandas as pd

sys.path.insert(0, f"{here()}/src")
from bias_correct import bias_correction
from hpo import hyperparameter_tuning
from prep_dataframe import prep_sex_train_data
from train import train
warnings.simplefilter(action='ignore', category=FutureWarning)

pd.set_option('mode.chained_assignment', None)
pd.set_option('display.max_columns', None)
pd.reset_option("mode.chained_assignment")
plt.style.use("ggplot")

# %% [markdown]
# - Grayed out section as this was done in the terminal using the ```hpo.py``` script

# %%
#hyperparameter_tuning('all')

# %%
#hyperparameter_tuning('male')

# %%
#hyperparameter_tuning('female')

# %% [markdown]
# ##### 1. Prepare Sex Data

# %%
#datem = datetime.today().strftime("%Y-%m-%d")

# %%
#X_male, Y_male, X_female, Y_female = prep_sex_train_data('../data/processed/df_train_sex.csv')

# %% [markdown]
# #### Load sex data

# %%
#X_male = pd.read_pickle(f"{here()}/data/train/x_train_male.pkl")
#X_female = pd.read_pickle(f"{here()}/data/train/x_train_female.pkl")
#Y_male = pd.read_pickle(f"{here()}/data/train/y_train_male.pkl")
#params = pd.read_pickle(f"{here()}/models/params/2024-07-10_male_best_params.pkl")

# %%
#X_male.shape, X_female.shape

# %% [markdown]
# #### 2. Train Male Data

# %%
train("male")
# Out:
# Validation Mean Absolute Error: 2.34
# Male Mean Absolute Error: 0.09
# Female Mean Absolute Error: 2.54
# All participants Mean Absolute Error: 1.23
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: /Users/waigwa/Documents/neptune/figures/male_feature_importance_plot.png

# %%
train("female")
# Out:
# Validation Mean Absolute Error: 2.47
# Male Mean Absolute Error: 2.43
# Female Mean Absolute Error: 0.89
# All participants Mean Absolute Error: 1.71
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: /Users/waigwa/Documents/neptune/figures/female_feature_importance_plot.png

# %%
train("all")
# Out:
# Validation Mean Absolute Error: 2.26
# Male Mean Absolute Error: 0.61
# Female Mean Absolute Error: 0.60
# All participants Mean Absolute Error: 0.61
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: /Users/waigwa/Documents/neptune/figures/all_feature_importance_plot.png

# %% [markdown]
# #### Bias Correction

# %%
bias_correction('all')
# Out:
# (2308, 187) (2308, 1)
# r: -0.4501435469242907, p-value: 0.0000
# min age: 3.25, median: 14.864999999999998, max: 30.0
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 199 rows containing missing values.
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: /Users/waigwa/Documents/neptune/figures/all_bag_age_plot.png
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 199 rows containing missing values.
# min age: 3.25, median: 14.864999999999998, max: 30.0
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 199 rows containing missing values.
# ...

# %%
bias_correction('male')
# Out:
# (1235, 187) (1235, 1)
# r: -0.4082345743153386, p-value: 0.0000
# min age: 3.4166666666666665, median: 14.583333333333334, max: 30.0
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 108 rows containing missing values.
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: /Users/waigwa/Documents/neptune/figures/male_bag_age_plot.png
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 108 rows containing missing values.
# min age: 3.4166666666666665, median: 14.583333333333334, max: 30.0
# ...

# %%
bias_correction('female')
# Out:
# (1073, 187) (1073, 1)
# r: -0.445183109278696, p-value: 0.0000
# min age: 3.25, median: 15.0, max: 30.0
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 91 rows containing missing values.
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: /Users/waigwa/Documents/neptune/figures/female_bag_age_plot.png
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 91 rows containing missing values.
# min age: 3.25, median: 15.0, max: 30.0
# /Users/waigwa/Documents/neptune/neptune/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 91 rows containing missing values.
# BAG-Age: -0.4452
#
# ...
